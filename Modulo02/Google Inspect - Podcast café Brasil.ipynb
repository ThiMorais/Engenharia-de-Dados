# %%
import requests
from bs4 import BeautifulSoup as bs
import logging
import pandas as pd

# %%
url = 'http://portalcafebrasil.com.br/todos/podcasts'

# %%
ret = requests.get(url)

# %%
ret.text
# Out:
# '\t<!DOCTYPE html>\n<html lang="pt-br">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n            <title>Arquivos Podcasts - Café Brasil</title>\n        <link href=\'https://fonts.googleapis.com/css?family=Open+Sans:400,600,700\' rel=\'stylesheet\' type=\'text/css\'>\n        <link href="https://portalcafebrasil.com.br/wp-content/themes/xpirit/css/bootstrap.min.css" rel="stylesheet">\n    <link href="https://portalcafebrasil.com.br/wp-content/themes/xpirit/style.css" rel="stylesheet">\n        <!--[if lt IE 9]>\n          <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n          <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n          <![endif]-->\n          \n        <meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n<!-- Google Tag 
# ...

# %%
soup = bs(ret.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Arquivos Podcasts - Café Brasil</title>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700" rel="stylesheet" type="text/css"/>
# <link href="https://portalcafebrasil.com.br/wp-content/themes/xpirit/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://portalcafebrasil.com.br/wp-content/themes/xpirit/style.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#           <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#           <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#           <![endif]-->
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- Google Tag Manager for WordPress by gtm4wp.com -->
# ...

# %%
soup.find('h5')
# Out:
# <h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-833-rio-beleza-e-caos/">Café Brasil 833 – Rio, beleza e caos</a></h5>

# %%
soup.find('h5').text
# Out:
# 'Café Brasil 833 – Rio, beleza e caos'

# %%
soup.find('h5').a['href']
# Out:
# 'https://portalcafebrasil.com.br/podcasts/cafe-brasil-833-rio-beleza-e-caos/'

# %%
lst_podcast = soup.find_all('h5')

# %%
for item in lst_podcast:
    print(f"EP: {item.text} - link: {item.a['href']}")
# Out:
# EP: Café Brasil 833 – Rio, beleza e caos - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-833-rio-beleza-e-caos/
# EP: Café Brasil 832 – Carta Aberta Ao Brasil – Revisitado - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-832-carta-aberta-ao-brasil-revisitado/
# EP: Café Brasil 831 – Nossos problemas - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-831-nossos-problemas/
# EP: Café Brasil 830 – Adultecer - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-830-adultecer/
# EP: Café Brasil 829 – Treine a mente! - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-829-treine-a-mente/
# EP: Café Brasil 828 – O catalisador - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-828-o-catalisador/
# EP: Café Brasil 827 – A complicada arte de ver – Revisitado - link: https://portalcafebrasil.com.br/podcasts/cafe-brasil-827-a-complicada-arte-de-ver-revisitado/
# ...

# %%
url = 'https://portalcafebrasil.com.br/todos/podcasts/page/{}/?ajax=true'

# %%
url.format(5)
# Out:
# 'https://portalcafebrasil.com.br/todos/podcasts/page/5/?ajax=true'

# %%
def get_podcast(url):
    ret = requests.get(url)
    soup = bs(ret.text)
    return soup.find_all('h5')

# %%
get_podcast(url.format(5))
# Out:
# [<h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-769-paulo-gustavo-e-as-48-horas/">Café Brasil 769 – Paulo Gustavo e as 48 horas</a></h5>,
#  <h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-768-a-expedicao-franklin/">Café Brasil 768 – A Expedição Franklin</a></h5>,
#  <h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-767-sexo-bom-revisitado/">Café Brasil 767 – Sexo bom – Revisitado</a></h5>,
#  <h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-766-lidercast-ilona-becskehazy/">Café Brasil 766 – LíderCast Ilona Becskeházy</a></h5>,
#  <h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-765-foxes-and-fossils/">Café Brasil 765 – Foxes and Fossils</a></h5>,
#  <h5><a href="https://portalcafebrasil.com.br/podcasts/cafe-brasil-764-lidercast-live-gastronomia-viva/">Café Brasil 764 – LíderCast Live – Gastronomia Viva</a></h5>,
# ...

# %%
log = logging.getLogger()
log.setLevel(logging.DEBUG)
formatter = logging.Formatter(
    '%(asctime)s - %(name)s - %(levelname)s - %(message)s')
ch = logging.StreamHandler()
ch.setFormatter(formatter)
log.addHandler(ch)

# %%
i = 1
lst_podcast = []
lst_get = get_podcast(url.format(i))
log.debug(f"Dados coletados do link: {url.format(i)} ")
                                      
while len(lst_get) > 0:
    lst_podcast = lst_podcast + lst_get
    i += 1
    lst_get = get_podcast(url.format(i))
    log.debug(f"Dados coletados do link: {url.format(i)}")
# Out:
# 2022-08-09 13:13:41,548 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): portalcafebrasil.com.br:443
# 2022-08-09 13:13:42,225 - urllib3.connectionpool - DEBUG - https://portalcafebrasil.com.br:443 "GET /todos/podcasts/page/1/?ajax=true HTTP/1.1" 301 0
# 2022-08-09 13:13:42,559 - urllib3.connectionpool - DEBUG - https://portalcafebrasil.com.br:443 "GET /todos/podcasts/?ajax=true HTTP/1.1" 200 None
# 2022-08-09 13:13:42,592 - root - DEBUG - Dados coletados do link: https://portalcafebrasil.com.br/todos/podcasts/page/1/?ajax=true
# 2022-08-09 13:13:42,594 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): portalcafebrasil.com.br:443
# 2022-08-09 13:13:43,323 - urllib3.connectionpool - DEBUG - https://portalcafebrasil.com.br:443 "GET /todos/podcasts/page/2/?ajax=true HTTP/1.1" 200 None
# 2022-08-09 13:13:43,358 - root - DEBUG - Dados coletados do link: https://portalcafebrasil.com.br/todos/podcasts/page/2/?ajax=true
# ...

# %%
len(lst_podcast)
# Out:
# 870

# %%
df = pd.DataFrame(columns = ['nome', 'link'])

# %%
for item in lst_podcast:
    df.loc[df.shape[0]] = [item.text, item.a['href']]

# %%
df.shape
# Out:
# (870, 2)

# %%
df.to_csv('banco_de_podcast.csv', sep=';', index=False)
